# %%
import os
rootDir = "music"
fileSet = set()

for dir_, _, files in os.walk(rootDir):
    for fileName in files:
        relDir = os.path.relpath(dir_, rootDir)
        relFile = os.path.join(relDir, fileName)
        fileSet.add(relFile)

# %%
from database.database import Database
database = Database()
for path in fileSet:
    #Audio.read_audio_file(path)
    print(path)
    database.add_songs(path)
# Out:
# ./Iron Horse - The_Four_Horsemen.mp3
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-de40bb096ff8> in <module>()
#       5     #Audio.read_audio_file(path)
#       6     print(path)
# ----> 7     database.add_songs(path)
#       8
#
# TypeError: add_songs() takes 1 positional argument but 2 were given

# %%
#get mic input
from audio_input.audio import Audio
A = Audio()
mic_input = A.read_mic(seconds=5)

# %%
len(mic_input)
#A.play_audio(mic_input)
# Out:
# 220500

# %%
#Convert to spectrogram and find peaks
differences = DFT.get_features(mic_input)



#Look for matches
match = DFT.best_match(differences)
	#Output best match TODO: format data better
print(database.get_song(match))

#Look for matches

	#Output best match

# %%
def filterlowamplitudes(C, threshold):
    """ Read

        Parameters
        ----------
        C: 2D numpy array of amplitudes from FFT
            Time on x, Frequency on y
        threshold: Threshold to determine high or low
        Returns
        -------
        2D boolean mask, True is high, False is low """
    m = np.copy(C)
    u = m < threshold
    ge = m > threshold
    m[u] = False
    m[ge] = True
    return m

# %%
import numpy as np
def getC(samples):
    C = np.fft.rfft(samples)
    #filterlowamplitudes(C, )
    return abs(C)

# %%
C = getC(mic_input)
print(np.mean(C))
C1 = filterlowamplitudes(C, np.mean(C)) * C
# Out:
# 156551.20662

# %%
import matplotlib.pyplot as plt

# numpy - for making data to plot
import numpy as np 

# this ensures plots show up in your notebook
# %matplotlib notebook

# %%
fig, ax = plt.subplots()

# you can use abbreviations for the keyword arguments:
# linestyle -> ls
# color -> c
ax.plot(C, color='green')
# Out:
# <img src="data:image/png;base64,..." width="640">
